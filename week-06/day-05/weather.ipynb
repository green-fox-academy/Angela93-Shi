# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weather_data=pd.read_csv("weatherHistory.csv")
weather_data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# 6      2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain
# 7      2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain
# 8      2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain
# 9      2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain
# 10     2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11     2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12     2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13     2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain
# ...

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
# Formatted Date              96453 non-null object
# Summary                     96453 non-null object
# Precip Type                 95936 non-null object
# Temperature (C)             96453 non-null float64
# Apparent Temperature (C)    96453 non-null float64
# Humidity                    96453 non-null float64
# Wind Speed (km/h)           96453 non-null float64
# Wind Bearing (degrees)      96453 non-null float64
# Visibility (km)             96453 non-null float64
# Loud Cover                  96453 non-null float64
# Pressure (millibars)        96453 non-null float64
# Daily Summary               96453 non-null object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
weather_data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
weather_data.drop(['Formatted Date','Summary','Precip Type','Daily Summary'],axis = 1, inplace =True)

# %%
weather_data.head()
# Out:
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
# 2         9.377778                  9.377778      0.89             3.9284
# 3         8.288889                  5.944444      0.83            14.1036
# 4         8.755556                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51

# %%
#analyze the relationship between the temperature and humidity
x_train = weather_data[['Humidity']]
y_train = weather_data[['Temperature (C)']]

# %%
from sklearn.linear_model import LinearRegression
linear_regression = LinearRegression()
linear_regression.fit(x_train,y_train)
y_predict_test = linear_regression.predict(x_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,y_pred_test,'r')
plt.title("Relationship between the temperature and humidity")
plt.xlabel("Humidity")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
#analyze the relationship between the apparent temperature and humidity

# %%
x_train2 = weather_data[["Humidity"]]
y_train2 = weather_data[['Apparent Temperature (C)']]

# %%
linear_regression.fit(x_train2,y_train2)
y_predict_test2 = linear_regression.predict(x_train2)

# %%
plt.scatter(x_train2,y_train2,c='g')
plt.plot(x_train2,y_predict_test2,c='y')
plt.title("Relationship between the Apparent Temperature and humidity")
plt.xlabel("Humidity")
plt.ylabel("Apparent Temperature")
# Out:
# Text(0, 0.5, 'Apparent Temperature')

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

# %%
cs = cross_val_score(linear_regression,x_train2,y_train2,cv=5)
cs.mean()
# Out:
# numpy.ndarray

# %%
#predict the apparent temperature by the given humidity
linear_regression.predict([[1.2]])
# Out:
# array([[-4.48143124]])

# %%
# y = kx + b,this is the "k"
linear_regression.coef_
# Out:
# array([[-32.97447006]])

# %%
# y = kx + b,this is the "b"
linear_regression.intercept_
# Out:
# array([35.08793284])
