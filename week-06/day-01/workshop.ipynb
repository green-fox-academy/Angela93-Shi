# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('googleplaystore.csv',index_col='App',encoding='utf-8')

# %%
df
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10841 entries, Photo Editor & Candy Camera & Grid & ScrapBook to iHoroscope - 2018 Daily Horoscope & Astrology
# Data columns (total 12 columns):
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.describe(include='all')
# Out:
#        Category       Rating Reviews                Size    Installs   Type  \
# count     10841  9367.000000   10841               10841       10841  10840
# unique       34          NaN    6002                 462          22      3
# top      FAMILY          NaN       0  Varies with device  1,000,000+   Free
# freq       1972          NaN     596                1695        1579  10039
# mean        NaN     4.193338     NaN                 NaN         NaN    NaN
# std         NaN     0.537431     NaN                 NaN         NaN    NaN
# min         NaN     1.000000     NaN                 NaN         NaN    NaN
# 25%         NaN     4.000000     NaN                 NaN         NaN    NaN
# 50%         NaN     4.300000     NaN                 NaN         NaN    NaN
# 75%         NaN     4.500000     NaN                 NaN         NaN    NaN
# max         NaN    19.000000     NaN                 NaN         NaN    NaN
#
# ...

# %%
df
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...

# %%
df.loc[['Pixel Draw - Number Art Coloring Book']]
# Out:
#                                              Category  Rating Reviews  Size  \
# App
# Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3     967  2.8M
#
#                                        Installs  Type Price Content Rating  \
# App
# Pixel Draw - Number Art Coloring Book  100,000+  Free     0       Everyone
#
#                                                         Genres   Last Updated  \
# App
# Pixel Draw - Number Art Coloring Book  Art & Design;Creativity  June 20, 2018
#
#                                       Current Ver Android Ver
# App
# Pixel Draw - Number Art Coloring Book         1.1  4.4 and up

# %%
df.loc[['Pixel Draw - Number Art Coloring Book','Beauty Selfie Camera','BestCam Selfie-selfie, beauty camera, photo editor']]
# Out:
#                                                           Category  Rating  \
# App
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
# Beauty Selfie Camera                                        BEAUTY     4.2
# BestCam Selfie-selfie, beauty camera, photo editor          BEAUTY     3.9
#
#                                                    Reviews  Size  Installs  \
# App
# Pixel Draw - Number Art Coloring Book                  967  2.8M  100,000+
# Beauty Selfie Camera                                  2225   52M  500,000+
# BestCam Selfie-selfie, beauty camera, photo editor    1739   21M  500,000+
#
#                                                     Type Price Content Rating  \
# App
# Pixel Draw - Number Art Coloring Book               Free     0       Everyone
# Beauty Selfie Camera                                Free     0       Everyone
# BestCam Selfie-selfie, beauty camera, photo editor  Free     0       Everyone
#
# ...

# %%
df.loc[:'Mandala Coloring Book']
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
# Paper flowers instructions                          ART_AND_DESIGN     4.4
# Smoke Effect Photo Maker - Smoke Editor             ART_AND_DESIGN     3.8
# Infinite Painter                                    ART_AND_DESIGN     4.1
# Garden Coloring Book                                ART_AND_DESIGN     4.4
# Kids Paint Free - Drawing Fun                       ART_AND_DESIGN     4.7
# Text on Photo - Fonteee                             ART_AND_DESIGN     4.4
# ...

# %%
df['Paper flowers instructions':'Text on Photo - Fonteee']['Rating']
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...

# %%
#df.loc[['Size':'Content Rating']]
a=list(df.columns).index('Size')
b=list(df.columns).index('Content Rating')
df.loc[:,list(df.columns[a+1:b])]
# Out:
#                                                        Installs  Type Price
# App
# Photo Editor & Candy Camera & Grid & ScrapBook          10,000+  Free     0
# Coloring book moana                                    500,000+  Free     0
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   5,000,000+  Free     0
# Sketch - Draw & Paint                               50,000,000+  Free     0
# Pixel Draw - Number Art Coloring Book                  100,000+  Free     0
# Paper flowers instructions                              50,000+  Free     0
# Smoke Effect Photo Maker - Smoke Editor                 50,000+  Free     0
# Infinite Painter                                     1,000,000+  Free     0
# Garden Coloring Book                                 1,000,000+  Free     0
# Kids Paint Free - Drawing Fun                           10,000+  Free     0
# Text on Photo - Fonteee                              1,000,000+  Free     0
# ...

# %%
df.loc[:,'Size':'Content Rating']
# Out:
#                                                                   Size  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                     19M
# Coloring book moana                                                14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps                8.7M
# Sketch - Draw & Paint                                              25M
# Pixel Draw - Number Art Coloring Book                             2.8M
# Paper flowers instructions                                        5.6M
# Smoke Effect Photo Maker - Smoke Editor                            19M
# Infinite Painter                                                   29M
# Garden Coloring Book                                               33M
# Kids Paint Free - Drawing Fun                                     3.1M
# Text on Photo - Fonteee                                            28M
# Name Art Photo Editor - Focus n Filters                            12M
# ...

# %%
df['Rating'].mean()
# Out:
# 4.193338315362448

# %%
df['Type'].value_counts(normalize=True) * 100
# Out:
# Free    92.610701
# Paid     7.380074
# 0        0.009225
# Name: Type, dtype: float64

# %%
# df1['Reviews']= (df1['Reviews'].replace(r'[KM]+$', '', regex=True).astype(float) * \
#                  df1['Reviews'].str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6]).astype(int))

df[df['Reviews'] == df['Reviews'].max()]
# Out:
#          Category  Rating     Reviews                Size        Installs  \
# App
# Facebook   SOCIAL     4.1  78158306.0  Varies with device  1,000,000,000+
#
#           Type Price Content Rating  Genres    Last Updated  \
# App
# Facebook  Free     0           Teen  Social  August 3, 2018
#
#                  Current Ver         Android Ver
# App
# Facebook  Varies with device  Varies with device

# %%
df[df['Reviews'] == df['Reviews'].min()]
# Out:
#                                                                Category  \
# App
# Truth or Dare Pro                                                DATING
# Private Dating, Hide App- Blue for PrivacyHider                  DATING
# Dating White Girls                                               DATING
# Geeks Dating                                                     DATING
# CAM5678 Video Chat                                               DATING
# Video chat live advices                                          DATING
# Pet Lovers Dating                                                DATING
# Latin Dating                                                     DATING
# Wifi Mingle                                                      DATING
# HOW TO ASK A GIRL OUT                                            DATING
# The DJ - Match with People                                       DATING
# Toronto Dating                                                   DATING
# ...

# %%
df.drop(['Life Made WI-Fi Touchscreen Photo Frame'], axis = 0)
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...

# %%
df[df['Last Updated'] == '1.0.19']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.drop(10472)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
df[df['Last Updated'] == '1.0.19']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df1 = df[(df['Last Updated'] != '1.0.19')]

# %%
df1[df1['Last Updated'] == '1.0.19']
# Out:
# Empty DataFrame
# Columns: [Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
import time
def struct_time(value):   
    struct_time = time.mktime(time.strptime(value, "%B %d, %Y"))
    return struct_time

df1['Last Updated Date'] = df1['Last Updated'].apply(struct_time)
df1
# Out:
# C:\Users\Angela_Shi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# ...

# %%
sorted_years = df1.sort_values(by=['Last Updated Date'], ascending=False)

sorted_years.head(10)
# Out:
#                                                              Category  Rating  \
# App
# Lalafo Pulsuz Elanlar                                        SHOPPING     4.4
# Video Downloader For FB: Save FB Videos 2018                    TOOLS     4.3
# Shoot Hunter-Gun Killer                                          GAME     4.3
# BankNordik                                                    FINANCE     3.9
# Fast Tract Diet                                    HEALTH_AND_FITNESS     4.4
# Fun Kid Racing - Motocross                                     FAMILY     4.1
# FD Calculator (EMI, SIP, RD & Loan Eligilibility)             FINANCE     5.0
# FG VOC                                                       BUSINESS     4.8
# HipChat - beta version                                  COMMUNICATION     4.1
# Monster Fishing 2018                                           SPORTS     4.4
#
#                                                   Reviews                Size  \
# App
# ...

# %%
df1.describe()
# df1['Last Updated Date'].quantile(q = 0.75)
# Out:
#             Rating  Last Updated Date
# count  9366.000000       1.084000e+04
# mean      4.191757       1.511218e+09
# std       0.515219       3.409439e+07
# min       1.000000       1.274371e+09
# 25%       4.000000       1.505837e+09
# 50%       4.300000       1.527091e+09
# 75%       4.500000       1.532016e+09
# max       5.000000       1.533658e+09

# %%
df2 = df1[( df1['Rating'] > 4.5 ) & ( df1['Last Updated Date'] > 1.533658e+09 - 60*24*60*60)]

# %%
df2
# Out:
#                                                                Category  \
# App
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Mandala Coloring Book                                    ART_AND_DESIGN
# Photo Designer - Write your name with shapes             ART_AND_DESIGN
# ibis Paint X                                             ART_AND_DESIGN
# Superheroes Wallpapers | 4K Backgrounds                  ART_AND_DESIGN
# HD Mickey Minnie Wallpapers                              ART_AND_DESIGN
# UNICORN - Color By Number & Pixel Art Coloring           ART_AND_DESIGN
# Canva: Poster, banner, card maker & graphic design       ART_AND_DESIGN
# Used Cars and Trucks for Sale                         AUTO_AND_VEHICLES
# Tickets SDA 2018 and Exam from the State Traffi...    AUTO_AND_VEHICLES
# CityBus Lviv                                          AUTO_AND_VEHICLES
# ...

# %%
df2 = df1[(df1['Size'] != 'Varies with device')]
sorted_size = df2.sort_values(by=['Size'], ascending=False)
# sorted_size
sorted_Rating=sorted_size.sort_values(by=['Rating'], ascending=True)
sorted_Rating
# Out:
#                                                             Category  Rating  \
# App
# CB Mobile Biz                                                FINANCE     1.0
# Tech CU Card Manager                                         FINANCE     1.0
# FE Mechanical Engineering Prep                                FAMILY     1.0
# Clarksburg AH                                                MEDICAL     1.0
# Speech Therapy: F                                             FAMILY     1.0
# DS Creator 2.0                                                 TOOLS     1.0
# House party - live chat                                       DATING     1.0
# Thistletown CI                                          PRODUCTIVITY     1.0
# Familial Hypercholesterolaemia Handbook                      MEDICAL     1.0
# CR Magazine                                                 BUSINESS     1.0
# Lottery Ticket Checker - Florida Results & Lotto               TOOLS     1.0
# ...

# %%
# df3 = df1[(df1['Rating'] != 'NaN')]
df3 = df1.fillna(0)

df3
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...
